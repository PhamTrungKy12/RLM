# %%
import requests

OLLAMA_URL = "http://localhost:11434/api/generate"
MODEL_NAME = "gemma3:4b"

def call_llm(prompt: str) -> str:
    response = requests.post(
        OLLAMA_URL,
        json={
            "model": MODEL_NAME,
            "prompt": prompt,
            "stream": False  # tắt streaming, đợi response hoàn chỉnh
        }
    )
    return response.json()["response"].strip()

# %%
data = call_llm("python là gì")

# %%
print(data)
# Out:
# Python là một ngôn ngữ lập trình bậc cao, đa năng và dễ học. Dưới đây là một cái nhìn tổng quan về Python:
#
# **1. Python là gì?**
#
# * **Ngôn ngữ lập trình:** Python là một công cụ cho phép bạn viết các hướng dẫn cho máy tính thực hiện các tác vụ cụ thể.
# * **Bậc cao:**  Nó trừ bỏ nhiều chi tiết phức tạp mà các ngôn ngữ lập trình cũ hơn yêu cầu, giúp bạn tập trung vào giải quyết vấn đề thay vì viết các dòng mã phức tạp.
# * **Đa năng:** Python có thể được sử dụng trong nhiều lĩnh vực khác nhau, bao gồm:
#     * **Phát triển web:** Tạo website, ứng dụng web.
#     * **Phân tích dữ liệu:**  Thống kê, trực quan hóa dữ liệu, học máy.
#     * **Học máy (Machine Learning):** Xây dựng các mô hình AI.
#     * **Lập trình khoa học:** Mô phỏng, phân tích dữ liệu khoa học.
#     * **Tự động hóa:**  Tự động hóa các tác vụ lặp đi lặp lại.
#     * **Phát triển game:** Tạo game đơn giản hoặc tích hợp vào các game lớn hơn.
#     * **Ứng dụng di động:**  Sử dụng các framework như Kivy hoặc BeeWare.
#
# **2. Đặc điểm nổi bật của Python:**
#
# * **Cú pháp dễ đọc, dễ học:** Python sử dụng cú pháp rõ ràng, gần giống tiếng Anh, giúp người mới bắt đầu dễ dàng làm quen.
# * **Cộng đồng lớn mạnh:** Cộng đồng Python rất lớn và tích cực, cung cấp nhiều tài liệu, thư viện, và hỗ trợ.
# * **Thư viện phong phú:** Python có một hệ thống thư viện cực kỳ phong phú, giúp bạn thực hiện nhiều tác vụ khác nhau mà không cần phải tự viết code từ đầu.  Một số thư viện phổ biến:
#     * **NumPy:** Tính toán số học
#     * **Pandas:**  Xử lý dữ liệu
#     * **Matplotlib & Seaborn:** Trực quan hóa dữ liệu
#     * **Scikit-learn:** Học máy
#     * **Django & Flask:**  Phát triển web
# * **Cross-platform:** Python có thể chạy trên nhiều hệ điều hành khác nhau (Windows, macOS, Linux).
# * **Dựa trên đối tượng (Object-oriented):** Python hỗ trợ lập trình hướng đối tượng, giúp tổ chức code một cách hiệu quả.
#
# **3. Ví dụ đơn giản về Python:**
#
# ```python
# # Đây là một chương trình Python đơn giản
# # in ra "Hello, world!"
# print("Hello, world!")
# ```
#
# **4. Nguồn tài liệu học Python:**
#
# * **Trang chủ Python:** [https://www.python.org/](https://www.python.org/)
# * **Tutorial Python:** [https://www.python.org/training/](https://www.python.org/training/)
# * **Codecademy:** [https://www.codecademy.com/learn/learn-python-3](https://www.codecademy.com/learn/learn-python-3)
# * **Coursera & edX:** Cung cấp nhiều khóa học Python.
#
# **Tóm lại, Python là một ngôn ngữ lập trình mạnh mẽ và linh hoạt, phù hợp cho cả người mới bắt đầu và các nhà phát triển có kinh nghiệm.  Nó là một lựa chọn tuyệt vời để giải quyết nhiều vấn đề khác nhau trong nhiều lĩnh vực khác nhau.**
#
# Bạn có muốn tôi giải thích thêm về một khía cạnh cụ thể của Python, chẳng hạn như:
#
# *   Các loại dữ liệu trong Python?
# *   Cách cài đặt Python?
# *   Các thư viện phổ biến hơn?
# *   Hoặc có lẽ bạn muốn tôi viết một chương trình Python đơn giản để bạn thử?
